# %%
import tsim
import stim
import time
import numpy as np

# %%
big = tsim.Circuit(
    """
    RX 346
Z_ERROR(0.01) 346
RX 326
Z_ERROR(0.01) 326
RX 327
Z_ERROR(0.01) 327
R 46
X_ERROR(0.01) 46
R 47
X_ERROR(0.01) 47
R 27
X_ERROR(0.01) 27
TICK
CX 346 46
DEPOLARIZE2(0.01) 346 46
CX 326 47
DEPOLARIZE2(0.01) 326 47
CX 327 27
DEPOLARIZE2(0.01) 327 27
TICK
CX 346 47
DEPOLARIZE2(0.01) 346 47
CX 326 27
DEPOLARIZE2(0.01) 326 27
RX 306
Z_ERROR(0.01) 306
RX 66
Z_ERROR(0.01) 66
TICK
CX 326 46
DEPOLARIZE2(0.01) 326 46
CX 327 47
DEPOLARIZE2(0.01) 327 47
CX 306 27
DEPOLARIZE2(0.01) 306 27
CX 66 346
DEPOLARIZE2(0.01) 66 346
RX 325
Z_ERROR(0.01) 325
RX 347
Z_ERROR(0.01) 347
RX 26
Z_ERROR(0.01) 26
TICK
CX 325 46
DEPOLARIZE2(0.01) 325 46
CX 347 47
DEPOLARIZE2(0.01) 347 47
CX 26 306
DEPOLARIZE2(0.01) 26 306
CX 346 66
DEPOLARIZE2(0.01) 346 66
TICK
CX 26 325
DEPOLARIZE2(0.01) 26 325
CX 47 347
DEPOLARIZE2(0.01) 47 347
CX 27 306
DEPOLARIZE2(0.01) 27 306
RX 67
Z_ERROR(0.01) 67
TICK
CX 46 325
DEPOLARIZE2(0.01) 46 325
CX 306 26
DEPOLARIZE2(0.01) 306 26
TICK
CX 325 26
DEPOLARIZE2(0.01) 325 26
TICK
S_DAG 26
TICK
CX 325 26
DEPOLARIZE2(0.01) 325 26
TICK
CX 306 26
DEPOLARIZE2(0.01) 306 26
RX 25
Z_ERROR(0.01) 25
RX 7
Z_ERROR(0.01) 7
TICK
CX 25 325
DEPOLARIZE2(0.01) 25 325
CX 7 306
DEPOLARIZE2(0.01) 7 306
TICK
CX 325 25
DEPOLARIZE2(0.01) 325 25
CX 306 7
DEPOLARIZE2(0.01) 306 7
TICK
TICK[EncodeT]
RX 306
Z_ERROR(0.01) 306
R 27
X_ERROR(0.01) 27
R 307
X_ERROR(0.01) 307
RX 47
Z_ERROR(0.01) 47
R 346
X_ERROR(0.01) 346
RX 325
Z_ERROR(0.01) 325
R 46
X_ERROR(0.01) 46
R 345
X_ERROR(0.01) 345
TICK
CX 7 307
DEPOLARIZE2(0.01) 7 307
CX 306 27
DEPOLARIZE2(0.01) 306 27
CX 47 346
DEPOLARIZE2(0.01) 47 346
CX 325 46
DEPOLARIZE2(0.01) 325 46
CX 66 345
DEPOLARIZE2(0.01) 66 345
TICK
CX 327 27
DEPOLARIZE2(0.01) 327 27
CX 7 306
DEPOLARIZE2(0.01) 7 306
CX 347 47
DEPOLARIZE2(0.01) 347 47
CX 66 346
DEPOLARIZE2(0.01) 66 346
CX 25 325
DEPOLARIZE2(0.01) 25 325
CX 326 46
DEPOLARIZE2(0.01) 326 46 
TICK
CX 307 7
DEPOLARIZE2(0.01) 307 7
CX 326 47
DEPOLARIZE2(0.01) 326 47
CX 26 325
DEPOLARIZE2(0.01) 26 325
CX 345 66
DEPOLARIZE2(0.01) 345 66

TICK
CX 26 306
DEPOLARIZE2(0.01) 26 306
CX 326 27
DEPOLARIZE2(0.01) 326 27
CX 327 47
DEPOLARIZE2(0.01) 327 47
CX 345 46
DEPOLARIZE2(0.01) 345 46
RX 66
Z_ERROR(0.01) 66

TICK
CX 306 26
DEPOLARIZE2(0.01) 306 26
CX 27 326
DEPOLARIZE2(0.01) 27 326
CX 47 327
DEPOLARIZE2(0.01) 47 327
CX 46 345
DEPOLARIZE2(0.01) 46 345

TICK
CX 27 327
DEPOLARIZE2(0.01) 27 327
CX 47 326
DEPOLARIZE2(0.01) 47 326
CX 325 25
DEPOLARIZE2(0.01) 325 25
CX 66 345
DEPOLARIZE2(0.01) 66 345

TICK
CX 27 307
DEPOLARIZE2(0.01) 27 307
CX 47 347
DEPOLARIZE2(0.01) 47 347
CX 346 66
DEPOLARIZE2(0.01) 346 66
CX 325 26
DEPOLARIZE2(0.01) 325 26
CX 46 326
DEPOLARIZE2(0.01) 46 326

TICK
CX 306 27
DEPOLARIZE2(0.01) 306 27
CX 47 346
DEPOLARIZE2(0.01) 47 346
CX 325 46
DEPOLARIZE2(0.01) 325 46
CX 345 66
DEPOLARIZE2(0.01) 345 66

TICK
Z_ERROR(0.01) 306
MX 306
DETECTOR[POST-SELECTION] rec[-1]
X_ERROR(0.01) 27
M 27
DETECTOR[POST-SELECTION] rec[-1]
X_ERROR(0.01) 7
M 7
DETECTOR[POST-SELECTION] rec[-1]
Z_ERROR(0.01) 47
MX 47
DETECTOR[POST-SELECTION] rec[-1]
X_ERROR(0.01) 346
M 346
DETECTOR[POST-SELECTION] rec[-1]
Z_ERROR(0.01) 325
MX 325
DETECTOR[POST-SELECTION] rec[-1]
X_ERROR(0.01) 46
M 46
DETECTOR[POST-SELECTION] rec[-1]
Z_ERROR(0.01) 345
MX 345
DETECTOR[POST-SELECTION] rec[-1]

TICK
TICK[Stabilize]
""")

# %%
c = tsim.Circuit(
    """
    RX 1 2 3
R 4 5 6
TICK
CX 1 4 2 5 3 6
TICK
CX 1 5 2 6
RX 7 8
TICK
CX 2 4 3 5 7 6 8 1
RX 9 10 11
TICK
CX 9 4 10 5 11 7 1 8
TICK
CX 11 9 5 10 6 7
RX 12
TICK
CX 4 9 7 11
TICK
CX 9 11
TICK
T_DAG 11
TICK
CX 9 11
TICK
CX 7 11
RX 13 14
TICK
CX 13 9 14 7
TICK
CX 9 13 7 14
TICK
TICK[EncodeT]
RX 7
R 6 15
RX 5
R 1
RX 9
R 4 16
TICK
CX 14 15 7 6 5 1 9 4 8 16
TICK
CX 3 6 14 7 10 5 8 1 13 9 2 4
TICK
CX 15 14 2 5 11 9 16 8
TICK
CX 11 7 2 6 3 5 16 4
RX 8
TICK
CX 7 11 6 2 5 3 4 16
TICK
CX 6 3 5 2 9 13 8 16
TICK
CX 6 15 5 10 1 8 9 11 4 2
TICK
CX 7 6 5 1 9 4 16 8
TICK
MX 7
DETECTOR[POST-SELECTION] rec[-1]
M 6
DETECTOR[POST-SELECTION] rec[-1]
M 14
DETECTOR[POST-SELECTION] rec[-1]
MX 5
DETECTOR[POST-SELECTION] rec[-1]
M 1
DETECTOR[POST-SELECTION] rec[-1]
MX 9
DETECTOR[POST-SELECTION] rec[-1]
M 4
DETECTOR[POST-SELECTION] rec[-1]
MX 16
DETECTOR[POST-SELECTION] rec[-1]
TICK
TICK[Stabilize]
RX 9 4 1 5 7 6
T_DAG 2 15 8 10 11 3 13
TICK
CX 9 13 4 2 1 8 5 10 7 11 6 15
TICK
CX 11 9 5 1 2 6
TICK
CX 2 11 5 3
TICK
CX 2 5
TICK
MX 2
DETECTOR[POST-SELECTION] rec[-1]
TICK[CheckT]
TICK
RX 2
TICK
CX 2 5
TICK
CX 2 11 5 3
TICK
CX 11 9 5 1 2 6
TICK
CX 9 13 4 2 1 8 5 10 7 11 6 15
TICK
T 2 15 8 10 11 3 13
MX 9
DETECTOR[POST-SELECTION] rec[-1]
MX 4
DETECTOR[POST-SELECTION] rec[-1]
MX 1
DETECTOR[POST-SELECTION] rec[-1]
MX 5
DETECTOR[POST-SELECTION] rec[-1]
MX 7
DETECTOR[POST-SELECTION] rec[-1]
MX 6
DETECTOR[POST-SELECTION] rec[-1]
TICK
TICK[CheckT]
TICK[SteaneCode]
"""
)
c.diagram(height=800)
# Out:
#     <div style="overflow-x: scroll; ">
#     <div style="width: 5600.0px">
#     <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 8288 1184" version="1.1">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L8256,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L8256,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L8256,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L8256,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L8256,320 " stroke="black"/>
# ...

# %%
big.diagram("pyzx")
# Out:
# <div style="overflow:auto; background-color: white" id="graph-output-kcbzzehc"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://esm.sh/d3@5"); }
# var _settings_colors = JSON.parse('{"edge": "#000000", "Hedge": "#0088ff", "Xedge": "#999999", "boundary": "#000000", "X": "#ff8888", "Y": "#aabbff", "Z": "#ccffcc", "H": "#ffff66", "W": "#000000", "Zalt": "#ccffcc", "Walt": "#000000", "Xdark": "#ff8888", "Ydark": "#aabbff", "Zdark": "#99dd99"}');
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
big.diagram(height=800)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 big.diagram(height=800)
#
# NameError: name 'big' is not defined

# %%
c = tsim.Circuit(
    """QUBIT_COORDS(0, 0) 0
 QUBIT_COORDS(0, 1) 1
 QUBIT_COORDS(1, 0) 2
 QUBIT_COORDS(1, 1) 3
 QUBIT_COORDS(1, 2) 4
 QUBIT_COORDS(2, 0) 5
 QUBIT_COORDS(2, 1) 6
 QUBIT_COORDS(2, 2) 7
 QUBIT_COORDS(2, 3) 8
 QUBIT_COORDS(3, 0) 9
 QUBIT_COORDS(3, 1) 10
 QUBIT_COORDS(3, 2) 11
 QUBIT_COORDS(3, 3) 12
 QUBIT_COORDS(3, 4) 13
 QUBIT_COORDS(4, 0) 14
 QUBIT_COORDS(4, 1) 15
 QUBIT_COORDS(4, 2) 16
 QUBIT_COORDS(4, 3) 17
 R 1 14
 RX 4 2 10 12
 R 0 9 16 11 6 3 13 8 7 5 17 15
 TICK
 CX 2 5 4 7 10 15 12 17
 TICK
 CX 2 3 5 6 7 8 10 11 12 13 15 16
 TICK
 CX 2 0 5 9 7 11 10 6 12 8
 TICK
 CX 4 3 7 6 10 9 12 11 17 16
 TICK
 CX 2 5 4 7 10 15 12 17
 TICK
 M 7 5 17 15
 MX 4 2 10 12

 DETECTOR(2, 2, 0) rec[-8]

 DETECTOR(2, 0, 0) rec[-7]

 DETECTOR(4, 3, 0) rec[-6]

 DETECTOR(4, 1, 0) rec[-5]
 TICK
 RX 4 2 10 12 15 14
 R 7 5 17
 TICK
 CX 2 5 4 7 10 6 12 17 15 16
 TICK
 CX 4 3 7 6 10 9 12 11 14 15 17 16
 TICK
 CX 2 3 5 6 7 8 10 11 12 13 16 15
 TICK
 CX 2 0 5 9 7 11 10 15 12 8
 TICK
 CX 2 5 4 7 12 17 15 14
 TICK
 T_DAG 13
 TICK
 M 17 5 7
 MX 15 10 16 13 2 4 12
 DETECTOR(4, 3, 1) rec[-10]
 DETECTOR(2, 0, 1) rec[-9]
 DETECTOR(2, 2, 1) rec[-8]
 DETECTOR(4, 1, 1) rec[-7]
 DETECTOR(4, 2, 1) rec[-5]

 DETECTOR(3, 1, 1) rec[-5] rec[-6] rec[-12]

 DETECTOR(1, 0, 1) rec[-3] rec[-13]
 DETECTOR(1, 2, 1) rec[-2] rec[-14]
 DETECTOR(3, 3, 1) rec[-1] rec[-11]
 TICK
 RX 2 4 10
 R 5 7 15
 TICK
 CX 2 5 4 7 10 15
 TICK
 CX 2 0 5 9 7 11 10 6
 TICK
 CX 2 3 5 6 7 8 10 11
 TICK
 CX 4 3 7 6 10 9 15 14
 TICK
 CX 0 2 6 10 9 5 11 7
 TICK
 CX 3 2 6 5 8 7 11 10
 TICK
 CX 3 4 6 7 9 10 14 15
 TICK
 CX 2 5 4 7 10 15
 TICK
 MX 2 4 10
 M 5 7 15
 DETECTOR(1.25, 0.25, 2, -1, -9) rec[-9] rec[-6]
 DETECTOR(1.5, 1.875, 2, -1, -9) rec[-8] rec[-5]
 DETECTOR(1.75, 0.25, 2, -1, -9) rec[-3]
 DETECTOR(2, 1.875, 2, -1, -9) rec[-2]
 DETECTOR(3, 0.875, 2, -1, -9) rec[-13] rec[-12] rec[-4]
 DETECTOR(3.5, 0.875, 2, -1, -9) rec[-1]
 TICK
 RX 15 10 5 2 7 1
 TICK
 T_DAG 0 3 6 8 9 11 14
 TICK
 CX 1 0 2 3 5 6 7 8 10 9 15 14
 TICK
 CX 3 1 6 7 10 15
 TICK
 CX 6 3 10 11
 TICK
 CX 6 10
 TICK
 MX 6
 TICK
 RX 6
 TICK
 CX 6 10
 TICK
 CX 6 3 10 11
 TICK
 CX 3 1 6 7 10 15
 TICK
 CX 1 0 2 3 5 6 7 8 10 9 15 14
 TICK
 T 0 3 6 8 9 11 14
 TICK
 MX 15 10 5 2 7 1
 DETECTOR(1.60714, 0.75, 3, -1, -9) rec[-29] rec[-28] rec[-26] rec[-24] rec[-23] rec[-21] rec[-20] rec[-18] rec[-17] rec[-12] rec[-11] rec[-7]
 DETECTOR(4, 1, 4) rec[-6]
 DETECTOR(3, 1, 4) rec[-5]
 DETECTOR(2, 1, 4) rec[-4] rec[-7]
 DETECTOR(1, 0, 4) rec[-3]
 DETECTOR(2, 2, 4) rec[-2]
 DETECTOR(0, 1, 4) rec[-1]
 TICK
 """)

c.diagram(height=150)
# Out:
#     <div style="overflow-x: scroll; ">
#     <div style="width: 757.6923076923077px">
#     <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 6304 1248" version="1.1">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L6272,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L6272,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L6272,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L6272,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L6272,320 " stroke="black"/>
# ...

# %%
c = tsim.Circuit(
    """QUBIT_COORDS(0, 0) 0
 QUBIT_COORDS(0, 1) 1
 QUBIT_COORDS(1, 0) 2
 QUBIT_COORDS(1, 1) 3
 QUBIT_COORDS(1, 2) 4
 QUBIT_COORDS(2, 0) 5
 QUBIT_COORDS(2, 1) 6
 QUBIT_COORDS(2, 2) 7
 QUBIT_COORDS(2, 3) 8
 QUBIT_COORDS(3, 0) 9
 QUBIT_COORDS(3, 1) 10
 QUBIT_COORDS(3, 2) 11
 QUBIT_COORDS(3, 3) 12
 QUBIT_COORDS(3, 4) 13
 QUBIT_COORDS(4, 0) 14
 QUBIT_COORDS(4, 1) 15
 QUBIT_COORDS(4, 2) 16
 QUBIT_COORDS(4, 3) 17
 R 1 14
 RX 4 2 10 12
 R 0 9 16 11 6 3 13 8 7 5 17 15
 TICK
 CX 2 5 4 7 10 15 12 17
 TICK
 CX 2 3 5 6 7 8 10 11 12 13 15 16
 TICK
 CX 2 0 5 9 7 11 10 6 12 8
 TICK
 CX 4 3 7 6 10 9 12 11 17 16
 TICK
 CX 2 5 4 7 10 15 12 17
 TICK
 M 7 5 17 15
 MX 4 2 10 12
 TICK
 RX 4 2 10 12 15 14
 R 7 5 17
 TICK
 CX 2 5 4 7 10 6 12 17 15 16
 TICK
 CX 4 3 7 6 10 9 12 11 14 15 17 16
 TICK
 CX 2 3 5 6 7 8 10 11 12 13 16 15
 TICK
 CX 2 0 5 9 7 11 10 15 12 8
 TICK
 CX 2 5 4 7 12 17 15 14
 TICK
 T_DAG 13
 TICK
 M 17 5 7
 MX 15 10 16 13 2 4 12
 TICK
 RX 2 4 10
 R 5 7 15
 TICK
 CX 2 5 4 7 10 15
 TICK
 CX 2 0 5 9 7 11 10 6
 TICK
 CX 2 3 5 6 7 8 10 11
 TICK
 CX 4 3 7 6 10 9 15 14
 TICK
 CX 0 2 6 10 9 5 11 7
 TICK
 CX 3 2 6 5 8 7 11 10
 TICK
 CX 3 4 6 7 9 10 14 15
 TICK
 CX 2 5 4 7 10 15
 TICK
 MX 2 4 10
 M 5 7 15
 TICK
 RX 15 10 5 2 7 1
 TICK
 T_DAG 0 3 6 8 9 11 14
 TICK
 CX 1 0 2 3 5 6 7 8 10 9 15 14
 TICK
 CX 3 1 6 7 10 15
 TICK
 CX 6 3 10 11
 TICK
 CX 6 10
 TICK
 MX 6
 TICK
 RX 6
 TICK
 CX 6 10
 TICK
 CX 6 3 10 11
 TICK
 CX 3 1 6 7 10 15
 TICK
 CX 1 0 2 3 5 6 7 8 10 9 15 14
 TICK
 T 0 3 6 8 9 11 14
 TICK
 MX 15 10 5 2 7 1
 TICK
 """)

# %%
g= c.diagram("pyzx", height=800)
# Out:
# <div style="overflow:auto; background-color: white" id="graph-output-vrNCN8VF"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://esm.sh/d3@5"); }
# var _settings_colors = JSON.parse('{"edge": "#000000", "Hedge": "#0088ff", "Xedge": "#999999", "boundary": "#000000", "X": "#ff8888", "Y": "#aabbff", "Z": "#ccffcc", "H": "#ffff66", "W": "#000000", "Zalt": "#ccffcc", "Walt": "#000000", "Xdark": "#ff8888", "Ydark": "#aabbff", "Zdark": "#99dd99"}');
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
g= c.diagram("pyzx")
# Out:
# <div style="overflow:auto; background-color: white" id="graph-output-DsUg9Uju"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://esm.sh/d3@5"); }
# var _settings_colors = JSON.parse('{"edge": "#000000", "Hedge": "#0088ff", "Xedge": "#999999", "boundary": "#000000", "X": "#ff8888", "Y": "#aabbff", "Z": "#ccffcc", "H": "#ffff66", "W": "#000000", "Zalt": "#ccffcc", "Walt": "#000000", "Xdark": "#ff8888", "Ydark": "#aabbff", "Zdark": "#99dd99"}');
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
c.diagram("pyzx-dets")
# Out:
# <div style="overflow:auto; background-color: white" id="graph-output-poz5XsVP"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://esm.sh/d3@5"); }
# var _settings_colors = JSON.parse('{"edge": "#000000", "Hedge": "#0088ff", "Xedge": "#999999", "boundary": "#000000", "X": "#ff8888", "Y": "#aabbff", "Z": "#ccffcc", "H": "#ffff66", "W": "#000000", "Zalt": "#ccffcc", "Walt": "#000000", "Xdark": "#ff8888", "Ydark": "#aabbff", "Zdark": "#99dd99"}');
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
sampler = c.compile_detector_sampler()

num_samples = 1024**2 *64

start = time.perf_counter()
samples = sampler.sample(shots=num_samples)
end = time.perf_counter()
print(f"Time per shot: {(end - start) * 1e9 / num_samples:.1f} ns")
# Out:
# Time per shot: 58.1 ns

# %%
sampler = c.compile_sampler()
samples = sampler.sample(100_000, batch_size=100_000)
print(f"Infidelity: {np.count_nonzero(samples) / len(samples)}")
c.diagram("timeline-svg", height=100)
# Out:
# Infidelity: 0.0
#     <div style="overflow-x: scroll; ">
#     <div style="width: 700.0px">
#     <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 8288 1184" version="1.1">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L8256,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L8256,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L8256,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L8256,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# ...

# %%
import pyzx as zx

# %%
zx.full_reduce(g)
zx.draw(g)

# %%
from tsim.core.graph import prepare_graph

# %%
p = prepare_graph(c, sample_detectors=True)

# %%
zx.draw(p.graph)

# %%
c = tsim.Circuit("""
R 0
M 0
DETECTOR rec[-1]
""")
c.diagram("pyzx")
# Out:
# <div style="overflow:auto; background-color: white" id="graph-output-eqtf1xNp"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://esm.sh/d3@5"); }
# var _settings_colors = JSON.parse('{"edge": "#000000", "Hedge": "#0088ff", "Xedge": "#999999", "boundary": "#000000", "X": "#ff8888", "Y": "#aabbff", "Z": "#ccffcc", "H": "#ffff66", "W": "#000000", "Zalt": "#ccffcc", "Walt": "#000000", "Xdark": "#ff8888", "Ydark": "#aabbff", "Zdark": "#99dd99"}');
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# ...
